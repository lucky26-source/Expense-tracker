# %%
expenses = []


def add_expense():
    name = input("Enter expense name: ")
    amount = float(input("Enter amount: "))

    expense = {
        "name": name,
        "amount": amount
    }

    expenses.append(expense)

    print("Expense added successfully!")


def view_expenses():
    if len(expenses) == 0:
        print("No expenses found.")
        return

    print("\n----- All Expenses -----")

    for expense in expenses:
        print(
            expense["name"],
            "- ₹",
            expense["amount"]
        )


def total_expenses():
    total = 0

    for expense in expenses:
        total += expense["amount"]

    print("Total Expenses: ₹", total)


def highest_expense():
    if len(expenses) == 0:
        print("No expenses found.")
        return

    highest = expenses[0]

    for expense in expenses:
        if expense["amount"] > highest["amount"]:
            highest = expense

    print(
        "Highest Expense:",
        highest["name"],
        "- ₹",
        highest["amount"]
    )


while True:

    print("\n===== EXPENSE TRACKER =====")
    print("1. Add Expense")
    print("2. View Expenses")
    print("3. Total Expenses")
    print("4. Highest Expense")
    print("5. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        add_expense()

    elif choice == "2":
        view_expenses()

    elif choice == "3":
        total_expenses()

    elif choice == "4":
        highest_expense()

    elif choice == "5":
        print("Thank you for using Expense Tracker!")
        break

    else:
        print("Invalid choice. Please try again.")
# Out:
# ===== EXPENSE TRACKER =====
# 1. Add Expense
# 2. View Expenses
# 3. Total Expenses
# 4. Highest Expense
# 5. Exit
# Enter your choice:  1
# Enter expense name:  sumanth
# Enter amount:  1000000
# Expense added successfully!
#
# ===== EXPENSE TRACKER =====
# 1. Add Expense
# 2. View Expenses
# 3. Total Expenses
# 4. Highest Expense
# 5. Exit
# Enter your choice:  2
# ----- All Expenses -----
# sumanth  - ₹ 1000000.0
#
# ===== EXPENSE TRACKER =====
# 1. Add Expense
# 2. View Expenses
# 3. Total Expenses
# 4. Highest Expense
# 5. Exit
# Enter your choice:  3
# Total Expenses: ₹ 1000000.0
#
# ===== EXPENSE TRACKER =====
# 1. Add Expense
# 2. View Expenses
# 3. Total Expenses
# 4. Highest Expense
# 5. Exit
# Enter your choice:  4
# Highest Expense: sumanth  - ₹ 1000000.0
#
# ===== EXPENSE TRACKER =====
# 1. Add Expense
# 2. View Expenses
# 3. Total Expenses
# 4. Highest Expense
# 5. Exit
# Enter your choice:  5
# Thank you for using Expense Tracker!
